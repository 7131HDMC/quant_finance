# %%
# !pip install opstrat

# %%
import opstrat as op
import matplotlib.pyplot as plt

# %%
plt.rcParams.update({
    "figure.facecolor":  '#c2d6d6',
    "axes.facecolor":    '#c2d6d6',
    "savefig.facecolor": '#c2d6d6'
})

# %%
op.single_plotter()

# %% [markdown]
# Option premium of 12.50 selling a put option at a strike price of 460 when the stock is also trading at 460.

# %%
op.single_plotter(spot=460, strike=460, op_type='p',
                  tr_type='s', op_pr=12.5)

# %% [markdown]
# **Short Strangle**
# A short strangle is an options trading strategy that involve:
# * selling of a slightly out-of-the-money put and
# * a slightly out-of-the-money call of the same underlying stock and expiration date

# %%
op_1 = {'op_type':'c','strike':110,'tr_type':'s','op_pr':2}
op_2 = {'op_type':'p','strike':95,'tr_type':'s','op_pr':6}
op.multi_plotter(spot=100, op_list=[op_1,op_2])
